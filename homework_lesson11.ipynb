# %%
from matplotlib import pyplot as plt

# %%
import math

# %%
import numpy as np

# %%
x = np.linspace(-math.pi, math.pi, 1000)

# %%
x = np.linspace(-math.pi, math.pi, 1000)
y1 = x**2
n = range(1000)
#y2 = (math.pi**2)/3 + sum((4*np.cos(n*x)*np.cos(math.pi*n))/n**2)
plt.plot(x, y1, label='y = x**2')
#plt.plot(x, y2, label='y = math.pi**2)/3 + sum((4*np.cos(n*x)*np.cos(math.pi*n))/n**2')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
x = np.linspace(-math.pi, math.pi, 1000)
y1 = x**2
plt.plot(x, y1, label='y = x**2')
n = 1
y2 = (math.pi**2)/3 + 4*np.cos(n*x)*np.cos(math.pi*n)/n**2
plt.plot(x, y2, label='y = (math.pi**2)/3 + sum((4*np.cos(n*x)*np.cos(math.pi*n))/n**2')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
